# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## IMÁGENES

# %%
#Cargar imágenes
marilyn = plt.imread('./Archivos/marilyn.png')
print(type(marilyn))
print(marilyn.shape)
# Out:
# <class 'numpy.ndarray'>
# (900, 1200, 3)

# %%
plt.imshow(marilyn)
plt.imshow(marilyn[:,:,1])

# %%
#Determinar la dimension de la matriz. Una vez hecho el producto tensorial con el kernel.
a = 64
b = 3
s = 1
c = np.floor(((a-b)/s)+1)
c
# Out:
# 62.0
